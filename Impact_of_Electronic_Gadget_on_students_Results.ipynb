# %% [markdown]
# <a href="https://colab.research.google.com/github/Subarna-Liza/ML/blob/main/Impact_of_Electronic_Gadget_on_students_Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
df=pd.read_csv('gdrive/My Drive/Colab Notebooks/The Impact of Electronic Gadget Uses with Academic Performance among University Students.csv')
df
# Out:
#              Timestamp  Gender Your study year  \
# 0   7/19/2022 12:26:34  Female               4
# 1    7/21/2022 2:19:26    Male   Post Graduate
# 2   7/21/2022 18:55:02    Male               3
# 3   8/22/2022 10:01:30  Female               3
# 4   8/22/2022 10:02:05    Male               2
# 5   8/22/2022 11:02:07    Male               1
# 6   8/22/2022 11:05:23  Female               4
# 7   8/22/2022 11:06:11    Male   Post Graduate
# 8   8/22/2022 11:08:11    Male               4
# 9   8/22/2022 11:09:17    Male               4
# 10  8/22/2022 11:11:51    Male               1
# 11  8/22/2022 11:12:40    Male               2
# 12  8/22/2022 11:14:14    Male               3
# 13  8/25/2022 19:23:20    Male               1
# 14  8/25/2022 19:24:21    Male               3
# 15   8/27/2022 3:14:25    Male               4
# 16   8/27/2022 3:15:01    Male   Post Graduate
# 17   8/27/2022 3:15:59    Male               4
# 18   8/27/2022 3:16:34  Female               1
# ...

# %% [markdown]
# #	Label encoding of Gender columns

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Gender']=le.fit_transform(df['Gender'])

# %%
df.head()
# Out:
#             Timestamp  Gender Your study year  \
# 0  7/19/2022 12:26:34       0               4
# 1   7/21/2022 2:19:26       1   Post Graduate
# 2  7/21/2022 18:55:02       1               3
# 3  8/22/2022 10:01:30       0               3
# 4  8/22/2022 10:02:05       1               2
#
#                    Which department  How many electronic devices do you use?  \
# 0            Information Technology                                        2
# 1               Business Management                                        4
# 2            Information Technology                                        3
# 3                       Engineering                                        3
# 4  Architecture & Built Environment                                        2
#
#   What is your recent latest CGPA ? Is there an increase in your CGPA?  \
# 0                         3.00-3.49                           Increase
# 1                         3.00-3.49                           decrease
# ...

# %% [markdown]
# # Mapping of "Your study year" column

# %%
df["Your study year"].value_counts()
# Out:
# 4                8
# 3                6
# 1                6
# Post Graduate    5
# 2                5
# Name: Your study year, dtype: int64

# %%
df["Your study year"] = df["Your study year"].str.replace(r"Post Graduate","4")

# %%
df["Your study year"].head()
# Out:
# 0    4
# 1    4
# 2    3
# 3    3
# 4    2
# Name: Your study year, dtype: object

# %%
df["Your study year"].dtypes
# Out:
# dtype('O')

# %%
df.head()
# Out:
#             Timestamp  Gender Your study year  \
# 0  7/19/2022 12:26:34       0               4
# 1   7/21/2022 2:19:26       1               4
# 2  7/21/2022 18:55:02       1               3
# 3  8/22/2022 10:01:30       0               3
# 4  8/22/2022 10:02:05       1               2
#
#                    Which department  How many electronic devices do you use?  \
# 0            Information Technology                                        2
# 1               Business Management                                        4
# 2            Information Technology                                        3
# 3                       Engineering                                        3
# 4  Architecture & Built Environment                                        2
#
#   What is your recent latest CGPA ? Is there an increase in your CGPA?  \
# 0                         3.00-3.49                           Increase
# 1                         3.00-3.49                           decrease
# ...

# %% [markdown]
# # Label encoding of**"Which department"** columns

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Which department']=le.fit_transform(df['Which department'])

# %%
df.head()
# Out:
#             Timestamp  Gender Your study year  Which department  \
# 0  7/19/2022 12:26:34       0               4                 7
# 1   7/21/2022 2:19:26       1               4                 2
# 2  7/21/2022 18:55:02       1               3                 7
# 3  8/22/2022 10:01:30       0               3                 5
# 4  8/22/2022 10:02:05       1               2                 1
#
#    How many electronic devices do you use? What is your recent latest CGPA ?  \
# 0                                        2                         3.00-3.49
# 1                                        4                         3.00-3.49
# 2                                        3                       3.50 - 3.99
# 3                                        3                         2.50-2.99
# 4                                        2                         3.00-3.49
#
#   Is there an increase in your CGPA?  \
# 0                           Increase
# 1                           decrease
# ...

# %% [markdown]
# # Mapping of "**What is your recent latest CGPA ?**" column

# %%
df["What is your recent latest CGPA ?"].value_counts()
# Out:
# 3.00-3.49      14
# 3.50 - 3.99     9
# 2.50-2.99       5
# 2.00-2.49       2
# Name: What is your recent latest CGPA ?, dtype: int64

# %%
df["What is your recent latest CGPA ?"]=df["What is your recent latest CGPA ?"].str.replace(r"3.00-3.49","0")
df["What is your recent latest CGPA ?"]=df["What is your recent latest CGPA ?"].str.replace(r"3.50 - 3.99","1")
df["What is your recent latest CGPA ?"]=df["What is your recent latest CGPA ?"].str.replace(r"2.50-2.99","2")
df["What is your recent latest CGPA ?"]=df["What is your recent latest CGPA ?"].str.replace(r"2.00-2.49","3")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.

# %%
df.head()
# Out:
#             Timestamp  Gender Your study year  Which department  \
# 0  7/19/2022 12:26:34       0               4                 7
# 1   7/21/2022 2:19:26       1               4                 2
# 2  7/21/2022 18:55:02       1               3                 7
# 3  8/22/2022 10:01:30       0               3                 5
# 4  8/22/2022 10:02:05       1               2                 1
#
#    How many electronic devices do you use? What is your recent latest CGPA ?  \
# 0                                        2                                 0
# 1                                        4                                 0
# 2                                        3                                 1
# 3                                        3                                 2
# 4                                        2                                 0
#
#   Is there an increase in your CGPA?  \
# 0                           Increase
# 1                           decrease
# ...

# %% [markdown]
# # Mapping of **"Is there an increase in your CGPA?"** column

# %%
df["Is there an increase in your CGPA?"].value_counts()
# Out:
# Increase    11
# None        11
# decrease     8
# Name: Is there an increase in your CGPA?, dtype: int64

# %%
df["Is there an increase in your CGPA?"]=df["Is there an increase in your CGPA?"].str.replace(r"Increase","0")
df["Is there an increase in your CGPA?"]=df["Is there an increase in your CGPA?"].str.replace(r"None","1")
df["Is there an increase in your CGPA?"]=df["Is there an increase in your CGPA?"].str.replace(r"decrease","2")

# %%
df.head()
# Out:
#             Timestamp  Gender Your study year  Which department  \
# 0  7/19/2022 12:26:34       0               4                 7
# 1   7/21/2022 2:19:26       1               4                 2
# 2  7/21/2022 18:55:02       1               3                 7
# 3  8/22/2022 10:01:30       0               3                 5
# 4  8/22/2022 10:02:05       1               2                 1
#
#    How many electronic devices do you use? What is your recent latest CGPA ?  \
# 0                                        2                                 0
# 1                                        4                                 0
# 2                                        3                                 1
# 3                                        3                                 2
# 4                                        2                                 0
#
#   Is there an increase in your CGPA?  \
# 0                                  0
# 1                                  2
# ...

# %% [markdown]
# # Label encoding of**"What is the purpose of buying the device?"** columns

# %%
df["What is the purpose of buying the device?"].value_counts()
# Out:
# Studies, Entertainment, Online class, games, Movies, Phone call    7
# Studies, Entertainment, Online class, Phone call                   7
# Studies, Entertainment                                             5
# Studies, Entertainment, Phone call                                 3
# Studies, Entertainment, Online class                               2
# Studies, Online class, Phone call                                  2
# Studies, Online class, games, Movies, Phone call                   1
# Studies, Entertainment, games, Movies, Phone call                  1
# Studies, Online class, Movies, Phone call                          1
# Online class, Movies, Phone call                                   1
# Name: What is the purpose of buying the device?, dtype: int64

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['What is the purpose of buying the device?']=le.fit_transform(df['What is the purpose of buying the device?'])

# %%
df.head()
# Out:
#             Timestamp  Gender Your study year  Which department  \
# 0  7/19/2022 12:26:34       0               4                 7
# 1   7/21/2022 2:19:26       1               4                 2
# 2  7/21/2022 18:55:02       1               3                 7
# 3  8/22/2022 10:01:30       0               3                 5
# 4  8/22/2022 10:02:05       1               2                 1
#
#    How many electronic devices do you use? What is your recent latest CGPA ?  \
# 0                                        2                                 0
# 1                                        4                                 0
# 2                                        3                                 1
# 3                                        3                                 2
# 4                                        2                                 0
#
#   Is there an increase in your CGPA?  \
# 0                                  0
# 1                                  2
# ...

# %% [markdown]
# # Label encoding of"**Average hour you spent using electronic devices for academic purposes in a day (hours).**" columns

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Average hour you spent using electronic devices for academic purposes in a day (hours).']=le.fit_transform(df['Average hour you spent using electronic devices for academic purposes in a day (hours).'])

# %%
df.head()
# Out:
#             Timestamp  Gender Your study year  Which department  \
# 0  7/19/2022 12:26:34       0               4                 7
# 1   7/21/2022 2:19:26       1               4                 2
# 2  7/21/2022 18:55:02       1               3                 7
# 3  8/22/2022 10:01:30       0               3                 5
# 4  8/22/2022 10:02:05       1               2                 1
#
#    How many electronic devices do you use? What is your recent latest CGPA ?  \
# 0                                        2                                 0
# 1                                        4                                 0
# 2                                        3                                 1
# 3                                        3                                 2
# 4                                        2                                 0
#
#   Is there an increase in your CGPA?  \
# 0                                  0
# 1                                  2
# ...

# %% [markdown]
# ## Dropping the unnessesary feature

# %%
feature_drop=['Timestamp']
df=df.drop(feature_drop,axis=1)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Gender Your study year  Which department  \
# 0        0               4                 7
# 1        1               4                 2
# 2        1               3                 7
# 3        0               3                 5
# 4        1               2                 1
# 5        1               1                 3
# 6        0               4                 2
# 7        1               4                 7
# 8        1               4                 4
# 9        1               4                 6
# 10       1               1                 5
# 11       1               2                 0
# 12       1               3                 1
# 13       1               1                 3
# 14       1               3                 3
# 15       1               4                 2
# 16       1               4                 4
# 17       1               4                 6
# 18       0               1                 5
# ...

# %%
df.head()
# Out:
#    Gender Your study year  Which department  \
# 0       0               4                 7
# 1       1               4                 2
# 2       1               3                 7
# 3       0               3                 5
# 4       1               2                 1
#
#    How many electronic devices do you use? What is your recent latest CGPA ?  \
# 0                                        2                                 0
# 1                                        4                                 0
# 2                                        3                                 1
# 3                                        3                                 2
# 4                                        2                                 0
#
#   Is there an increase in your CGPA?  \
# 0                                  0
# 1                                  2
# 2                                  0
# 3                                  2
# 4                                  0
#
# ...

# %%
y=df.iloc[:,5:6]
y.head()
# Out:
#   Is there an increase in your CGPA?
# 0                                  0
# 1                                  2
# 2                                  0
# 3                                  2
# 4                                  0

# %%
y
# Out:
#    Is there an increase in your CGPA?
# 0                                   0
# 1                                   2
# 2                                   0
# 3                                   2
# 4                                   0
# 5                                   1
# 6                                   2
# 7                                   2
# 8                                   1
# 9                                   0
# 10                                  1
# 11                                  0
# 12                                  0
# 13                                  2
# 14                                  0
# 15                                  1
# 16                                  0
# 17                                  1
# 18                                  1
# 19                                  0
# 20                                  0
# 21                                  2
# 22                                  1
# 23                                  2
# ...

# %%
x=df.drop(['Is there an increase in your CGPA?'],axis=1)
x
# Out:
#     Gender Your study year  Which department  \
# 0        0               4                 7
# 1        1               4                 2
# 2        1               3                 7
# 3        0               3                 5
# 4        1               2                 1
# 5        1               1                 3
# 6        0               4                 2
# 7        1               4                 7
# 8        1               4                 4
# 9        1               4                 6
# 10       1               1                 5
# 11       1               2                 0
# 12       1               3                 1
# 13       1               1                 3
# 14       1               3                 3
# 15       1               4                 2
# 16       1               4                 4
# 17       1               4                 6
# 18       0               1                 5
# 19       0               2                 2
# ...

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.15,random_state=0)

# %%
xtrain
# Out:
#     Gender Your study year  Which department  \
# 24       1               4                 5
# 27       1               1                 0
# 11       1               2                 0
# 17       1               4                 6
# 22       1               3                 4
# 5        1               1                 3
# 16       1               4                 4
# 8        1               4                 4
# 14       1               3                 3
# 23       1               2                 2
# 20       0               1                 7
# 1        1               4                 2
# 29       0               4                 2
# 6        0               4                 2
# 4        1               2                 1
# 18       0               1                 5
# 19       0               2                 2
# 9        1               4                 6
# 7        1               4                 7
# 25       0               3                 7
# ...

# %%
ytrain
# Out:
#    Is there an increase in your CGPA?
# 24                                  0
# 27                                  1
# 11                                  0
# 17                                  1
# 22                                  1
# 5                                   1
# 16                                  0
# 8                                   1
# 14                                  0
# 23                                  2
# 20                                  0
# 1                                   2
# 29                                  2
# 6                                   2
# 4                                   0
# 18                                  1
# 19                                  0
# 9                                   0
# 7                                   2
# 25                                  1
# 3                                   2
# 0                                   0
# 21                                  2
# 15                                  1
# ...

# %%
xtest
# Out:
#     Gender Your study year  Which department  \
# 2        1               3                 7
# 28       0               4                 3
# 13       1               1                 3
# 10       1               1                 5
# 26       0               4                 1
#
#     How many electronic devices do you use? What is your recent latest CGPA ?  \
# 2                                         3                                 1
# 28                                        4                                 0
# 13                                        2                                 3
# 10                                        2                                 2
# 26                                        2                                 1
#
#     Average hour you spent using electronic devices for academic purposes in a day (hours).  \
# 2                                                   3
# 28                                                  4
# ...

# %%
ytest
# Out:
#    Is there an increase in your CGPA?
# 2                                   0
# 28                                  1
# 13                                  2
# 10                                  1
# 26                                  1

# %% [markdown]
# # Decesion Tree implementation

# %%
from sklearn import tree
DT=tree.DecisionTreeClassifier()

# %%
model=DT.fit(xtrain,ytrain)

# %%
accuracy_test=model.score(xtest,ytest)

# %%
accuracy_test
# Out:
# 0.6

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier()

# %%
RF.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier()

# %%
RF_Accuracy_test_data=RF.score(xtest,ytest)

# %%
RF_Accuracy_test_data
# Out:
# 0.4

# %% [markdown]
# # Support Vector Machine Analysis SVM (Before scalling)

# %%
from sklearn.svm import SVC
SM=SVC()

# %%
SM.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
SM.score(xtest,ytest)
# Out:
# 0.2

# %% [markdown]
# # Linear Regression implementation

# %%
from sklearn.linear_model import LinearRegression
Reg=LinearRegression()

# %%
Reg.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
Reg.score(xtest,ytest)
# Out:
# -1.4688201898190658

# %%
Reg.score(xtrain,ytrain)
# Out:
# 0.3190886704594754

# %% [markdown]
# # KNN Algorithm Implementation

# %%
xtrain.value_counts()
# Out:
# Gender  Your study year  Which department  How many electronic devices do you use?  What is your recent latest CGPA ?  Average hour you spent using electronic devices for academic purposes in a day (hours).  What is the purpose of buying the device?
# 0       1                5                 3                                        0                                  1                                                                                        4                                            1
# 1       2                2                 2                                        0                                  4                                                                                        4                                            1
# ...

# %%
x.shape
# Out:
# (30, 7)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
k=5
neigh=KNeighborsClassifier(n_neighbors=k)
neigh.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
 pred_y=neigh.predict(xtest)
 print("Accuracy of model at k =5 ",metrics.accuracy_score(ytest,pred_y))
# Out:
# Accuracy of model at k =5  0.2

# %% [markdown]
# # Feature scalling

# %%
df
# Out:
#     Gender Your study year  Which department  \
# 0        0               4                 7
# 1        1               4                 2
# 2        1               3                 7
# 3        0               3                 5
# 4        1               2                 1
# 5        1               1                 3
# 6        0               4                 2
# 7        1               4                 7
# 8        1               4                 4
# 9        1               4                 6
# 10       1               1                 5
# 11       1               2                 0
# 12       1               3                 1
# 13       1               1                 3
# 14       1               3                 3
# 15       1               4                 2
# 16       1               4                 4
# 17       1               4                 6
# 18       0               1                 5
# 19       0               2                 2
# ...

# %%
df.shape
# Out:
# (30, 8)

# %%
x_after = x

# %%
x_after
# Out:
#     Gender Your study year  Which department  \
# 0        0               4                 7
# 1        1               4                 2
# 2        1               3                 7
# 3        0               3                 5
# 4        1               2                 1
# 5        1               1                 3
# 6        0               4                 2
# 7        1               4                 7
# 8        1               4                 4
# 9        1               4                 6
# 10       1               1                 5
# 11       1               2                 0
# 12       1               3                 1
# 13       1               1                 3
# 14       1               3                 3
# 15       1               4                 2
# 16       1               4                 4
# 17       1               4                 6
# 18       0               1                 5
# 19       0               2                 2
# ...

# %%
from sklearn.preprocessing import StandardScaler
STANDERDISATION=StandardScaler()
x_after_scalling=STANDERDISATION.fit_transform(Z)
