# %% [markdown]
# <a href="https://colab.research.google.com/github/Subarna-Liza/ML/blob/main/Breast_Cancer_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Breast Cancer Detection Implementation

# %% [markdown]
# # Csv Read

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('gdrive/My Drive/Colab Notebooks/Breast Cancer.csv')

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# ## Data Visualization (Part-01)

# %% [markdown]
# # import library for data Visualization

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
# %matplotlib inline

# %% [markdown]
# # Question:01=> How many people were at what stage of cancer

# %%
sns.countplot('diagnosis',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# # Data Preprocessing

# %%
df.shape
# Out:
# (569, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# # Label encoding of diagnosis column

# %%
df['diagnosis']
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['diagnosis']=le.fit_transform(df['diagnosis'])

# %%
df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %% [markdown]
# # Converting int to float of **diagosis** column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    int64
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df['diagnosis']=df['diagnosis'].astype(float)

# %%
df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302        1.0        17.99         10.38          122.80
# 1      842517        1.0        20.57         17.77          132.90
# 2    84300903        1.0        19.69         21.25          130.00
# 3    84348301        1.0        11.42         20.38           77.58
# 4    84358402        1.0        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424        1.0        21.56         22.39          142.00
# 565    926682        1.0        20.13         28.25          131.20
# 566    926954        1.0        16.60         28.08          108.30
# 567    927241        1.0        20.60         29.33          140.10
# 568     92751        0.0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %% [markdown]
# # Converting int to float of **ID** column

# %%
df['id']=df['id'].astype(float)

# %%
df
# Out:
#              id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302.0        1.0        17.99         10.38          122.80
# 1      842517.0        1.0        20.57         17.77          132.90
# 2    84300903.0        1.0        19.69         21.25          130.00
# 3    84348301.0        1.0        11.42         20.38           77.58
# 4    84358402.0        1.0        20.29         14.34          135.10
# ..          ...        ...          ...           ...             ...
# 564    926424.0        1.0        21.56         22.39          142.00
# 565    926682.0        1.0        20.13         28.25          131.20
# 566    926954.0        1.0        16.60         28.08          108.30
# 567    927241.0        1.0        20.60         29.33          140.10
# 568     92751.0        0.0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    float64
#  1   diagnosis                569 non-null    float64
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
# ...

# %% [markdown]
# # Missing value cheaking

# %%
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %% [markdown]
# # Data Visualization (Part-02)

# %% [markdown]
# # Pair plot

# %%
sns.pairplot(df.iloc[:,1:7],hue='diagnosis')

# %% [markdown]
# # Correlation

# %%
df.iloc[:,1:12].corr()
# Out:
#                         diagnosis  radius_mean  texture_mean  perimeter_mean  \
# diagnosis                1.000000     0.730029      0.415185        0.742636
# radius_mean              0.730029     1.000000      0.323782        0.997855
# texture_mean             0.415185     0.323782      1.000000        0.329533
# perimeter_mean           0.742636     0.997855      0.329533        1.000000
# area_mean                0.708984     0.987357      0.321086        0.986507
# smoothness_mean          0.358560     0.170581     -0.023389        0.207278
# compactness_mean         0.596534     0.506124      0.236702        0.556936
# concavity_mean           0.696360     0.676764      0.302418        0.716136
# concave points_mean      0.776614     0.822529      0.293464        0.850977
# symmetry_mean            0.330499     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.012838    -0.311631     -0.076437       -0.261477
#
# ...

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.iloc[:,1:12].corr(),annot=True)

# %%
df
# Out:
#              id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302.0        1.0        17.99         10.38          122.80
# 1      842517.0        1.0        20.57         17.77          132.90
# 2    84300903.0        1.0        19.69         21.25          130.00
# 3    84348301.0        1.0        11.42         20.38           77.58
# 4    84358402.0        1.0        20.29         14.34          135.10
# ..          ...        ...          ...           ...             ...
# 564    926424.0        1.0        21.56         22.39          142.00
# 565    926682.0        1.0        20.13         28.25          131.20
# 566    926954.0        1.0        16.60         28.08          108.30
# 567    927241.0        1.0        20.60         29.33          140.10
# 568     92751.0        0.0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# ...

# %% [markdown]
# # find out the **feature** and **target** attribute

# %%
y=df.iloc[:,1:2]

# %%
y
# Out:
#      diagnosis
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# ..         ...
# 564        1.0
# 565        1.0
# 566        1.0
# 567        1.0
# 568        0.0
#
# [569 rows x 1 columns]

# %%
df.drop('diagnosis',axis=1,inplace=True)

# %%
df
# Out:
#              id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302.0        17.99         10.38          122.80     1001.0
# 1      842517.0        20.57         17.77          132.90     1326.0
# 2    84300903.0        19.69         21.25          130.00     1203.0
# 3    84348301.0        11.42         20.38           77.58      386.1
# 4    84358402.0        20.29         14.34          135.10     1297.0
# ..          ...          ...           ...             ...        ...
# 564    926424.0        21.56         22.39          142.00     1479.0
# 565    926682.0        20.13         28.25          131.20     1261.0
# 566    926954.0        16.60         28.08          108.30      858.1
# 567    927241.0        20.60         29.33          140.10     1265.0
# 568     92751.0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df.shape
# Out:
# (569, 31)

# %%
x=df.iloc[:,0:31]

# %%
x
# Out:
#              id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302.0        17.99         10.38          122.80     1001.0
# 1      842517.0        20.57         17.77          132.90     1326.0
# 2    84300903.0        19.69         21.25          130.00     1203.0
# 3    84348301.0        11.42         20.38           77.58      386.1
# 4    84358402.0        20.29         14.34          135.10     1297.0
# ..          ...          ...           ...             ...        ...
# 564    926424.0        21.56         22.39          142.00     1479.0
# 565    926682.0        20.13         28.25          131.20     1261.0
# 566    926954.0        16.60         28.08          108.30      858.1
# 567    927241.0        20.60         29.33          140.10     1265.0
# 568     92751.0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
x.shape
# Out:
# (569, 31)

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.30)

# %%
xtrain
# Out:
#              id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 9    84501001.0       12.460         24.04           83.97      475.9
# 235  88249602.0       14.030         21.25           89.79      603.4
# 105    863030.0       13.110         15.56           87.21      530.2
# 277   8911670.0       18.810         19.98          120.90     1102.0
# 63     859196.0        9.173         13.86           59.20      260.9
# ..          ...          ...           ...             ...        ...
# 549    923465.0       10.820         24.21           68.89      361.6
# 188    874662.0       11.810         17.39           75.27      428.9
# 428  90769601.0       11.130         16.62           70.47      381.1
# 26     852763.0       14.580         21.53           97.41      644.8
# 205    879523.0       15.120         16.68           98.78      716.6
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
ytrain
# Out:
#      diagnosis
# 9          1.0
# 235        0.0
# 105        1.0
# 277        1.0
# 63         0.0
# ..         ...
# 549        0.0
# 188        0.0
# 428        0.0
# 26         1.0
# 205        1.0
#
# [398 rows x 1 columns]

# %%
xtest
# Out:
#              id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 166     87127.0       10.800          9.71           68.77      357.6
# 59     858477.0        8.618         11.79           54.34      224.5
# 234    882488.0        9.567         15.91           60.21      279.6
# 418    906024.0       12.700         12.17           80.88      495.0
# 281   8912055.0       11.740         14.02           74.24      427.3
# ..          ...          ...           ...             ...        ...
# 516    916799.0       18.310         20.58          120.80     1052.0
# 186    874217.0       18.310         18.58          118.60     1041.0
# 546    922577.0       10.320         16.35           65.31      324.9
# 260    887549.0       20.310         27.06          132.90     1288.0
# 147  86973701.0       14.950         18.77           97.84      689.5
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
ytest
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-4907a4a98164> in <module>()
# ----> 1 ytest
#
# NameError: name 'ytest' is not defined

# %% [markdown]
# # Linear Regression implementation (**Before** **scalling**)

# %%
from sklearn.linear_model import LinearRegression
Reg=LinearRegression()

# %%
Reg.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
Reg.score(xtest,ytest)
# Out:
# 0.701409972835539

# %%
Reg.score(xtrain,ytrain)
# Out:
# 0.7939751328372059

# %% [markdown]
# # KNN Algorithm Implementation (**Before** **scalling**)

# %% [markdown]
# # find out the value of **K**

# %%
xtrain.value_counts()
# Out:
# id           radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  area_se  smoothness_se  compactness_se  concavity_se  concave points_se  symmetry_se  fractal_dimension_se  radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  compactness_worst  concavity_worst  concave points_worst  symmetry_worst  fractal_dimension_worst
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn import metrics

# %%
k=21

# %%
neigh=KNeighborsClassifier(n_neighbors=k)

# %%
neigh.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=21)

# %%
 pred_y=neigh.predict(xtest)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e1a952d78c5c> in <module>()
# ----> 1 pred_y=neigh.predict(xtest)
#
# NameError: name 'neigh' is not defined

# %%
print("Accuracy of model at k =21 ",metrics.accuracy_score(ytest,pred_y))
# Out:
# Accuracy of model at k =21  0.6491228070175439

# %% [markdown]
# # Decesion Tree implementation

# %%
from sklearn import tree

# %%
DT=tree.DecisionTreeClassifier()

# %%
model=DT.fit(xtrain,ytrain)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6c2b111b5549> in <module>()
# ----> 1 model=DT.fit(xtrain,ytrain)
#
# NameError: name 'DT' is not defined

# %%
accuracy_test=model.score(xtest,ytest)

# %%
accuracy_test
# Out:
# 0.9181286549707602

# %%
accuracy_train=model.score(xtrain,ytrain)

# %%
accuracy_train
# Out:
# 1.0

# %% [markdown]
# # Accuracy visualization of Decision tree algorithm

# %%
DT_x=["Train_Dataset","Test_Dataset"]
DT_y=[accuracy_train,accuracy_test]
c=["pink","skyblue"]
plt.bar(DT_x,DT_y,color=c)
plt.xlabel("Dataset type")
plt.ylabel("Accuracy Rate")
plt.title("Accuracy visualization of Decision tree algorithm")
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier()

# %%
RF.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier()

# %%
RF_Accuracy_train_data=RF.score(xtrain,ytrain)

# %%
RF_Accuracy_train_data
# Out:
# 1.0

# %%
RF_Accuracy_test_data=RF.score(xtest,ytest)

# %%
RF_Accuracy_test_data
# Out:
# 0.9473684210526315

# %% [markdown]
# # Accuracy visualization of Random Forest Algorithm

# %%
RF_x=["Train_Dataset","Test_Dataset"]
RF_y=[RF_Accuracy_train_data,RF_Accuracy_test_data]
c=["orange","purple"]
plt.bar(RF_x,RF_y,color=c)
plt.xlabel("Dataset type")
plt.ylabel("Accuracy Rate")
plt.title("Accuracy visualization of Random forest algorithm")
plt.show()

# %% [markdown]
# # Naive Bayes Implementation

# %% [markdown]
# # Gaussian NB

# %%
from sklearn.naive_bayes import GaussianNB

# %%
GNB=GaussianNB()

# %%
GNB.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
GNB.score(xtest,ytest)
# Out:
# 0.5964912280701754

# %%
GNB.score(xtrain,ytrain)
# Out:
# 0.6381909547738693

# %% [markdown]
# # Bernoulli NB

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
BNB=BernoulliNB()

# %%
BNB.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# BernoulliNB()

# %%
BNB.score(xtest,ytest)
# Out:
# 0.5964912280701754

# %%
BNB.score(xtrain,ytrain)
# Out:
# 0.6407035175879398

# %% [markdown]
# # Multinomial NB

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
MNB=MultinomialNB()

# %%
MNB.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MultinomialNB()

# %%
MNB.score(xtest,ytest)
# Out:
# 0.4327485380116959

# %%
MNB.score(xtrain,ytrain)
# Out:
# 0.3693467336683417

# %% [markdown]
# # Support Vector Machine Analysis **SVM** (**Before** **scalling**)

# %%
from sklearn.svm import SVC

# %%
SM=SVC()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-97d60089194e> in <module>()
# ----> 1 SM=SVC()
#
# NameError: name 'SVC' is not defined

# %%
SM.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
SM.score(xtest,ytest)
# Out:
# 0.5964912280701754

# %%
SM.score(xtrain,ytrain)
# Out:
# 0.6407035175879398

# %% [markdown]
# # Feature scalling

# %%
df
# Out:
#              id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302.0        17.99         10.38          122.80     1001.0
# 1      842517.0        20.57         17.77          132.90     1326.0
# 2    84300903.0        19.69         21.25          130.00     1203.0
# 3    84348301.0        11.42         20.38           77.58      386.1
# 4    84358402.0        20.29         14.34          135.10     1297.0
# ..          ...          ...           ...             ...        ...
# 564    926424.0        21.56         22.39          142.00     1479.0
# 565    926682.0        20.13         28.25          131.20     1261.0
# 566    926954.0        16.60         28.08          108.30      858.1
# 567    927241.0        20.60         29.33          140.10     1265.0
# 568     92751.0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df
# Out:
#              id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302.0        17.99         10.38          122.80     1001.0
# 1      842517.0        20.57         17.77          132.90     1326.0
# 2    84300903.0        19.69         21.25          130.00     1203.0
# 3    84348301.0        11.42         20.38           77.58      386.1
# 4    84358402.0        20.29         14.34          135.10     1297.0
# ..          ...          ...           ...             ...        ...
# 564    926424.0        21.56         22.39          142.00     1479.0
# 565    926682.0        20.13         28.25          131.20     1261.0
# 566    926954.0        16.60         28.08          108.30      858.1
# 567    927241.0        20.60         29.33          140.10     1265.0
# 568     92751.0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df.shape
# Out:
# (569, 31)

# %%
Z=df.iloc[:,0:31]

# %%
Z
# Out:
#              id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302.0        17.99         10.38          122.80     1001.0
# 1      842517.0        20.57         17.77          132.90     1326.0
# 2    84300903.0        19.69         21.25          130.00     1203.0
# 3    84348301.0        11.42         20.38           77.58      386.1
# 4    84358402.0        20.29         14.34          135.10     1297.0
# ..          ...          ...           ...             ...        ...
# 564    926424.0        21.56         22.39          142.00     1479.0
# 565    926682.0        20.13         28.25          131.20     1261.0
# 566    926954.0        16.60         28.08          108.30      858.1
# 567    927241.0        20.60         29.33          140.10     1265.0
# 568     92751.0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
Z.shape
# Out:
# (569, 31)

# %%
from sklearn.preprocessing import StandardScaler

# %%
STANDERDISATION=StandardScaler()

# %%
x_after=STANDERDISATION.fit_transform(Z)

# %%
x_after
# Out:
# array([[-0.23640517,  1.09706398, -2.07333501, ...,  2.29607613,
#          2.75062224,  1.93701461],
#        [-0.23640344,  1.82982061, -0.35363241, ...,  1.0870843 ,
#         -0.24388967,  0.28118999],
#        [ 0.43174109,  1.57988811,  0.45618695, ...,  1.95500035,
#          1.152255  ,  0.20139121],
#        ...,
#        [-0.23572747,  0.70228425,  2.0455738 , ...,  0.41406869,
#         -1.10454895, -0.31840916],
#        [-0.23572517,  1.83834103,  2.33645719, ...,  2.28998549,
#          1.91908301,  2.21963528],
#        [-0.24240586, -1.80840125,  1.22179204, ..., -1.74506282,
#         -0.04813821, -0.75120669]])

# %%
df
# Out:
#              id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302.0        17.99         10.38          122.80     1001.0
# 1      842517.0        20.57         17.77          132.90     1326.0
# 2    84300903.0        19.69         21.25          130.00     1203.0
# 3    84348301.0        11.42         20.38           77.58      386.1
# 4    84358402.0        20.29         14.34          135.10     1297.0
# ..          ...          ...           ...             ...        ...
# 564    926424.0        21.56         22.39          142.00     1479.0
# 565    926682.0        20.13         28.25          131.20     1261.0
# 566    926954.0        16.60         28.08          108.30      858.1
# 567    927241.0        20.60         29.33          140.10     1265.0
# 568     92751.0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain1,xtest1,ytrain1,ytest1=train_test_split(x_after,y,test_size=.30)

# %%
xtrain1
# Out:
# array([[-0.24244486, -0.09011536,  1.03795373, ...,  1.32005124,
#          2.47721732,  1.36623169],
#        [-0.24246219, -0.27188444, -0.14652343, ...,  1.43425072,
#          1.61655804,  1.88159879],
#        [-0.23614966,  1.18794852, -0.16513997, ...,  0.64703563,
#          0.49381829, -0.80717667],
#        ...,
#        [-0.23589773, -0.63542262,  0.43757041, ..., -0.48688908,
#          0.28188903, -0.57830934],
#        [ 0.43623308,  0.56879758,  0.32354413, ...,  1.41141082,
#          1.3027086 ,  1.67656027],
#        [-0.23584971, -0.74902829, -1.09363975, ..., -0.61357437,
#          0.06510643,  0.43524596]])

# %%
xtrain1.shape
# Out:
# (398, 31)

# %% [markdown]
# # (**SVM**)  Support vactor Machine (**after** **feature** **scalling**)

# %%
from sklearn.svm import SVC
model=SVC()

# %%
model.fit(xtrain1,ytrain1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
SVM_Accuracy_test_data=model.score(xtest1,ytest1)

# %%
SVM_Accuracy_test_data
# Out:
# 0.9649122807017544

# %%
SVM_Accuracy_train_data=model.score(xtrain1,ytrain1)

# %%
SVM_Accuracy_train_data
# Out:
# 0.9874371859296482

# %% [markdown]
# # Accuracy visualization of SVM (Support Vector Machine)

# %%
SM_x=["Train_Dataset","Test_Dataset"]
SM_y=[SVM_Accuracy_train_data,SVM_Accuracy_test_data]
c=["green","yellow"]
plt.bar(SM_x,SM_y,color=c)
plt.xlabel("Dataset type")
plt.ylabel("Accuracy Rate")
plt.title("Accuracy visualization of SVM algorithm")
plt.show()

# %% [markdown]
# ## Linear Regression implementation(**after** **feature** **scalling**)

# %%
from sklearn.linear_model import LinearRegression

# %%
LinearRegression=LinearRegression()

# %%
LinearRegression.fit(xtrain1,ytrain1)
# Out:
# LinearRegression()

# %%
LinearRegression.score(xtest1,ytest1)
# Out:
# 0.710697451084589

# %%
LinearRegression.score(xtrain1,ytrain1)
# Out:
# 0.7911248570239545

# %% [markdown]
# # **KNN** Algorithom implementation(**after** **feature** **scalling**)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k=23

# %%
model=KNeighborsClassifier(n_neighbors=k)

# %%
model.fit(xtrain1,ytrain1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=23)

# %%
KNN_Accuracy_test_data=model.score(xtest1,ytest1)

# %%
KNN_Accuracy_test_data
# Out:
# 0.9532163742690059

# %%
KNN_Accuracy_train_data=model.score(xtrain1,ytrain1)

# %%
KNN_Accuracy_train_data
# Out:
# 0.9597989949748744

# %% [markdown]
# # Accuracy visualizatrion of KNN algorithm

# %%
KNN_x=["Train_Dataset","Test_Dataset"]
KNN_y=[KNN_Accuracy_train_data,KNN_Accuracy_test_data]
c=["red","gray"]
plt.bar(KNN_x,KNN_y,color=c)
plt.xlabel("Dataset type")
plt.ylabel("Accuracy Rate")
plt.title("Accuracy visualization of KNN algorithm")
plt.show()
